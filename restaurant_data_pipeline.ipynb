# %%
import pandas as pd
import numpy as np

df = pd.read_csv("restaurant_data.csv")

# Clean column names
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

print(df.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.ensemble import IsolationForest

df = pd.read_csv("restaurant_data.csv")  # load dataset

# %%
# Remove outlier rows if you decide to drop
clean_df = df_imputed[~df_imputed["is_outlier"]].copy()

# Drop helper column if not needed
clean_df = clean_df.drop(columns=["is_outlier"])

# Save cleaned CSV
clean_df.to_csv("restaurant_data_cleaned.csv", index=False)
